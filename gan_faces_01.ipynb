# %%
from __future__ import division
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from glob import glob
import time
import os

from ops import *
from utils import *

# %% [markdown]
# Today we are going to train GAN for generating faces and then we will make fun playing with it. Generative adversarial networks (GANs) are deep neural net architectures comprised of two nets, pitting one against the other (thus the “adversarial”). One neural network, called the generator, generates new faces, while the other, the discriminator,  decides whether each instance of face it reviews belongs to the actual training dataset or not.
#
# Firstly download aligned faces of celebrities from here <a href="https://yadi.sk/d/xjuClJJH3MAVXh">link</a> and extract them into folder near ipython notebook.

# %% [markdown]
# ## Get the Data
#
# The data has been downloaded and resized before the instructor shared the new url to download the data. So, skipped.

# %%
"""
import zipfile
with zipfile.ZipFile('img_align_celeba.zip') as zf:
    zf.extractall()
"""

# %% [markdown]
# # Implementation of GAN

# %% [markdown]
# Constant variables below depends on your dataset and choosing of architecture.

# %%
DATA_PATH = './celebA_resized/' # Path to the dataset with celebA faces
Z_DIM=100 # Dimension of face's manifold
GENERATOR_DENSE_SIZE=2048 # Length of first tensor in generator

IMAGE_SIZE=64 # Shapes of input image
BATCH_SIZE=64 # Batch size
N_CHANNELS = 3 # Number channels of input image

MERGE_X = 8 # Number images in merged image
MERGE_Y = 8

# %%
assert(os.path.exists(DATA_PATH)), 'Please, download aligned celebA to DATA_PATH folder'

# %% [markdown]
# Let's define GAN. To do it, we need to define generator, discriminator and loss functions.

# %% [markdown]
# Here are some tips on the architecture of the generator:
# 1. The deeper is convolution, the less filters is using.
# 2. Apply deconvolutions-relu layers to achieve input image shape.
# 3. Use batch normalization before nonlinearity for speed and stability of learning.
# 4. Use tanh activation at the end of network (in this case images should be scaled to [-1, 1])
# 5. To force generator not to collapse and produce different outputs initialize bias with zero (see linear layer).
#
# Other useful tips: https://github.com/soumith/ganhacks. Example of architecture see below. You may also use defined layers from ops.py. <b> Please, use names for layers started with "g\_" for generator and "d_" for discriminator.</b>

# %% [markdown]
# <img src="https://raw.githubusercontent.com/carpedm20/DCGAN-tensorflow/master/DCGAN.png">

# %% [markdown]
# ### Resize the Images to 64-64-3

# %% [markdown]
# The images downloaded from the 3-rd party link other than the broken link provided by the course is of size 178-218-3, we need to resize them to 64-64-3 so that the GAN can directly use

# %%
"""
file_list = os.listdir(DATA_PATH)
RESIZED_DATA_PATH = './celebA_resized/'
if not os.path.exists(RESIZED_DATA_PATH):
    os.makedirs(RESIZED_DATA_PATH)
import cv2
counter = 0
for f in file_list:
    file_path = os.path.join(DATA_PATH, f)
    img = cv2.imread(file_path)
    img = cv2.resize(img, (64, 64))
    #img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    file_path = os.path.join(RESIZED_DATA_PATH, f)
    cv2.imwrite(file_path, img)
    counter += 1
    if counter % 1000 == 0:
        print("%d images have been resized."%counter)
"""
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-5769b9e1bbfc> in <module>()
#      11     #img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#      12     file_path = os.path.join(RESIZED_DATA_PATH, f)
# ---> 13     cv2.imwrite(file_path, img)
#      14     counter += 1
#      15     if counter % 1000 == 0:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Writing generator function (1 point)

# %%
def generator(z, is_training):
    # Firstly let's reshape input vector into 3-d tensor. 
    z_ = linear(z, GENERATOR_DENSE_SIZE * 4 * 4, 'g_h0_lin')
    h_in = tf.reshape(z_, [-1, 4, 4, GENERATOR_DENSE_SIZE])
    """
        Your code goes here.
    """
    g_bn0 = batch_norm(name='g_bn0')
    g_bn1 = batch_norm(name='g_bn1')
    g_bn2 = batch_norm(name='g_bn2')
    g_bn3 = batch_norm(name='g_bn3')
    
    h_in = tf.nn.relu(g_bn0(h_in))
    
    h1, h1_w, h1_b = deconv2d(h_in, [BATCH_SIZE, 8, 8, 512], name = 'g_h1', with_w=True)
    h1 = tf.nn.relu(g_bn1(h1))
    
    h2, h2_w, h2_b = deconv2d(h1, [BATCH_SIZE, 16, 16, 256], name = 'g_h2', with_w=True)
    h2 = tf.nn.relu(g_bn2(h2))
    
    h3, h3_w, h3_b = deconv2d(h2, [BATCH_SIZE, 32, 32, 128], name = 'g_h3', with_w=True)
    h3 = tf.nn.relu(g_bn3(h3))
    
    h_out, h4_w, h4_b = deconv2d(h3, [BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, N_CHANNELS],
            name='g_out', with_w=True)

    return tf.nn.tanh(h_out)

# %% [markdown]
# Now let's define discriminator. Discriminator takes 3d tensor as input and outputs one number - probability that this is an image.
#
# Some advice for discriminator's architecture:
# 1. Use batch normalization between convolutions and nonlinearities.
# 2. Use leaky relu with the leak about 0.2.
# 3. The deeper the layer, the more filters you can use.
#
# If you use batch normalization, please define every layer in their own scope and pass is_training parameter there. Or you may use class of batch normalization from ops.py. Do not forget to fratten tensor after the convolution blocks.

# %% [markdown]
# ## Writing discriminator function (1 point)

# %%
def discriminator(image, is_training, batch_norms=None):
    """
        Your code goes here.
    """
    d_bn1 = batch_norm(name='d_bn1')

    d_bn2 = batch_norm(name='d_bn2')
    
    d_bn3 = batch_norm(name='d_bn3')
    
    h0 = lrelu(conv2d(image, 64, name='d_h0_conv'))

    h1 = lrelu(d_bn1(conv2d(h0, 64*2, name='d_h1_conv')))

    h2 = lrelu(d_bn2(conv2d(h1, 64*4, name='d_h2_conv')))

    h3 = lrelu(d_bn3(conv2d(h2, 64*8, name='d_h3_conv')))
    
    #print(h3.shape)

    linear_out = linear(tf.reshape(h3, [BATCH_SIZE, -1]), 1, 'd_h4_lin')
    
    return tf.nn.sigmoid(linear_out), linear_out

# %% [markdown]
# Now let's define generator and discriminator.

# %%
tf.reset_default_graph()
is_training = tf.placeholder(tf.bool, name='is_training')

with tf.variable_scope("G") as scope:
    #scope.reuse_variables()
    z = tf.placeholder(tf.float32, [None, Z_DIM], name='z')
    G = generator(z, is_training)
    scope.reuse_variables()

with tf.variable_scope('D') as scope:
    images = tf.placeholder(tf.float32, shape=[BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, N_CHANNELS])
    
    # If you use batch norms from ops define them here (like batch_norms = [batch_norm(name='d_bn0')])
    # and pass to discriminator function instances.
    D_real, D_real_logits = discriminator(images, is_training)
    scope.reuse_variables()
    D_fake, D_fake_logits = discriminator(G, is_training)

# %% [markdown]
# Write definition of loss funstions according to formulas:
# $$ D\_loss = \frac{-1}{m} \sum_{i=1}^{m}[\log{D(x_i)} + \log{(1 - D(G(z_i)))}]$$
# $$ G\_loss = \frac{1}{m} \sum_{i=1}^{m} \log{(1 - D(G(z_i)))}$$
#
# Or for better learning you may try other loss for generator:
# $$ G\_loss = \frac{-1}{m} \sum_{i=1}^{m} \log{(D(G(z_i)))}$$

# %% [markdown]
# ## Writing loss functions (2 points)

# %%
"""
        You code goes here. Define discriminator and generator losses
"""

def sigmoid_cross_entropy_with_logits(x, y):

      try:

        return tf.nn.sigmoid_cross_entropy_with_logits(logits=x, labels=y)

      except:

        return tf.nn.sigmoid_cross_entropy_with_logits(logits=x, targets=y)
    
d_loss_real = tf.reduce_mean(sigmoid_cross_entropy_with_logits(D_real_logits, tf.ones_like(D_real)))

d_loss_fake = tf.reduce_mean(sigmoid_cross_entropy_with_logits(D_fake_logits, tf.zeros_like(D_fake)))

d_loss = d_loss_real + d_loss_fake

g_loss = tf.reduce_mean(sigmoid_cross_entropy_with_logits(D_fake_logits, tf.ones_like(D_fake)))

# %% [markdown]
# Create optimizers. We use different optimizers for discriminator and generator, so we needed a separate prefix for the discriminator and generator variables (g_ for generator, d_ for disciminator).

# %%
tvars = tf.trainable_variables()
## All variables of discriminator
d_vars = [v for v in tvars if 'd_' in v.name]

## All variables of generator
g_vars = [v for v in tvars if 'g_' in v.name]

LEARNING_RATE = 0.0001 # Learning rate for adam optimizer
BETA = 0.5 # Beta paramater in adam optimizer

##Optimizers - ypu may use your favourite instead.
d_optim = tf.train.AdamOptimizer(LEARNING_RATE, beta1=BETA) \
                  .minimize(d_loss, var_list=d_vars)
g_optim = tf.train.AdamOptimizer(LEARNING_RATE, beta1=BETA) \
                  .minimize(g_loss, var_list=g_vars)

# %% [markdown]
# Load data:

# %%
data = glob(os.path.join(DATA_PATH, "*.jpg"))
assert(len(data) > 0), "Length of training data should be more than zero"

# %% [markdown]
# Functions for training and evaluations.

# %%
def load(sess, load_dir):
    """load network's paramaters
    
    load_dir : path to load dir
    """
    saver = tf.train.Saver()
    ckpt = tf.train.get_checkpoint_state(load_dir)
    if ckpt and ckpt.model_checkpoint_path:
            saver.restore(sess, ckpt.model_checkpoint_path)

# %% [markdown]
# ## Training GAN (1 point + 2 for good results)

# %%
def train(sess, load_dir=None, save_frequency=1000, sample_frequency=1000, progress_frequency= 200, sample_dir='sample_faces',
          save_dir='checkpoint', max_to_keep=1, model_name='dcgan.model',
          n_epochs=20, n_generator_update=2):
    """train gan
    Parameters
    -------------------------------------------
    load_dir : str, default = None
        path to the folder with parameters
    save_frequency: int, default = 100
        how often save parameters []
    sample_frequency: int, default = None (not sample)
        how often sample faces
    sample_dir: str, default = samples
        directory for sampled images
    save_dir: str, default = 'checkpoint'
        path where to save parameters
    max_to_keep: int, default = 1
        how many last checkpoints to store
    model_name: str, default='dcgan.model'
        name of model
    n_epochs: int, default = 25 
        number epochs to train
    n_generator_update: int, default = 2
        how many times run generator updates per one discriminator update
    -------------------------------------------
    """
    
    if save_frequency is not None:
        saver = tf.train.Saver(max_to_keep=max_to_keep)
        
    if load_dir is not None:
        print("Reading checkpoints...")
        load(sess, load_dir)
        print("Loaded checkpoints")
    else:
        try:
            tf.global_variables_initializer().run()
        except:
            tf.initialize_all_variables().run()

    counter=1
    start_time = time.time()
    
    for epoch in range(n_epochs):
        batch_idxs = min(len(data), np.inf) // BATCH_SIZE
        counter = 1
        for idx in range(0, batch_idxs):
            batch_files = data[idx*BATCH_SIZE:(idx+1)*BATCH_SIZE]
            batch = [get_image(batch_file, IMAGE_SIZE) for batch_file in batch_files]
            batch_images = np.array(batch).astype(np.float32)
            batch_z = np.random.uniform(-1, 1, [BATCH_SIZE, Z_DIM]).astype(np.float32)

            # Update D network
            sess.run(d_optim, feed_dict={images: batch_images, z: batch_z,is_training: True})

            # Update G network
            for _ in range(n_generator_update):
                sess.run(g_optim,
                    feed_dict={z: batch_z, is_training: True})

            errD_fake = d_loss_fake.eval({z: batch_z, is_training: False})
            errD_real = d_loss_real.eval({images: batch_images, is_training: False})
            errG = g_loss.eval({z: batch_z, is_training: False})

            counter += 1
            if np.mod(counter, progress_frequency) == 1:
                print("Epoch: [{:2d}] [{:4d}/{:4d}] time: {:4.4f}, d_loss: {:.8f}, g_loss: {:.8f}".format(
                    epoch, idx, batch_idxs, time.time() - start_time, errD_fake+errD_real, errG))
                start_time = time.time()
            if np.mod(counter, save_frequency) == 1:
                print("Saved model, epoch=%d, counter=%d"%(epoch, counter))
                saver.save(sess, 
                           os.path.join(save_dir, model_name))

            if np.mod(counter, sample_frequency) == 1 or counter == batch_idxs + 1:
                samples = sess.run(G, feed_dict={z: batch_z, is_training: False} )
                print("epoch=%d, counter=%d"%(epoch, counter))
                save_images(samples, [MERGE_X, MERGE_Y],
                            os.path.join(sample_dir, 'train_{:02d}_{:04d}.png'.format(epoch, idx+1)))

# %%
with tf.Session() as sess:
    train(sess, save_dir='checkpoint')
# Out:
# Epoch: [ 0] [ 199/3165] time: 87.8456, d_loss: 1.15654445, g_loss: 0.82520777
# Epoch: [ 0] [ 399/3165] time: 87.4223, d_loss: 1.82868671, g_loss: 0.54028487
# Epoch: [ 0] [ 599/3165] time: 88.1895, d_loss: 1.47649026, g_loss: 0.69802701
# Epoch: [ 0] [ 799/3165] time: 88.5901, d_loss: 1.46630883, g_loss: 0.63227367
# Epoch: [ 0] [ 999/3165] time: 93.9302, d_loss: 1.66606832, g_loss: 0.56911981
# Saved model, epoch=0, counter=1001
# epoch=0, counter=1001
# Epoch: [ 0] [1199/3165] time: 101.3515, d_loss: 1.53818727, g_loss: 0.62075359
# Epoch: [ 0] [1399/3165] time: 95.9326, d_loss: 1.54210401, g_loss: 0.65766996
# Epoch: [ 0] [1599/3165] time: 96.0591, d_loss: 1.56097400, g_loss: 0.59713244
# Epoch: [ 0] [1799/3165] time: 96.1744, d_loss: 1.43594360, g_loss: 0.58439934
# Epoch: [ 0] [1999/3165] time: 95.4841, d_loss: 1.44779301, g_loss: 0.70621812
# Saved model, epoch=0, counter=2001
# epoch=0, counter=2001
# Epoch: [ 0] [2199/3165] time: 96.1772, d_loss: 1.44008887, g_loss: 0.68511117
# Epoch: [ 0] [2399/3165] time: 95.9807, d_loss: 1.49459147, g_loss: 0.60674506
# Epoch: [ 0] [2599/3165] time: 96.1827, d_loss: 1.44187331, g_loss: 0.68490410
# Epoch: [ 0] [2799/3165] time: 95.8943, d_loss: 1.43217254, g_loss: 0.64346349
# Epoch: [ 0] [2999/3165] time: 95.8977, d_loss: 1.47802424, g_loss: 0.58643198
# Saved model, epoch=0, counter=3001
# epoch=0, counter=3001
# epoch=0, counter=3166
# Epoch: [ 1] [ 199/3165] time: 169.0050, d_loss: 1.44286346, g_loss: 0.59570783
# Epoch: [ 1] [ 399/3165] time: 87.3892, d_loss: 1.41923118, g_loss: 0.66809613
# Epoch: [ 1] [ 599/3165] time: 87.4073, d_loss: 1.49105179, g_loss: 0.62647760
# Epoch: [ 1] [ 799/3165] time: 87.2253, d_loss: 1.45188665, g_loss: 0.59319609
# Epoch: [ 1] [ 999/3165] time: 87.6178, d_loss: 1.42227221, g_loss: 0.73843265
# Saved model, epoch=1, counter=1001
# epoch=1, counter=1001
# Epoch: [ 1] [1199/3165] time: 90.1462, d_loss: 1.43067265, g_loss: 0.64215636
# Epoch: [ 1] [1399/3165] time: 87.6393, d_loss: 1.48433483, g_loss: 0.59156525
# Epoch: [ 1] [1599/3165] time: 88.3939, d_loss: 1.40435433, g_loss: 0.68583477
# Epoch: [ 1] [1799/3165] time: 87.9135, d_loss: 1.38518620, g_loss: 0.70099080
# Epoch: [ 1] [1999/3165] time: 88.3123, d_loss: 1.53360844, g_loss: 0.56883550
# Saved model, epoch=1, counter=2001
# epoch=1, counter=2001
# Epoch: [ 1] [2199/3165] time: 90.5838, d_loss: 1.50981081, g_loss: 0.67509663
# Epoch: [ 1] [2399/3165] time: 87.4731, d_loss: 1.39664638, g_loss: 0.66530985
# Epoch: [ 1] [2599/3165] time: 87.6695, d_loss: 1.45721078, g_loss: 0.68150449
# Epoch: [ 1] [2799/3165] time: 87.4711, d_loss: 1.41245925, g_loss: 0.66453874
# Epoch: [ 1] [2999/3165] time: 87.4191, d_loss: 1.47341835, g_loss: 0.66120356
# Saved model, epoch=1, counter=3001
# epoch=1, counter=3001
# epoch=1, counter=3166
# Epoch: [ 2] [ 199/3165] time: 162.7024, d_loss: 1.39883125, g_loss: 0.59673154
# Epoch: [ 2] [ 399/3165] time: 87.6082, d_loss: 1.50010014, g_loss: 0.63061762
# Epoch: [ 2] [ 599/3165] time: 87.7774, d_loss: 1.41712093, g_loss: 0.66358674
# Epoch: [ 2] [ 799/3165] time: 88.0052, d_loss: 1.39507234, g_loss: 0.62460428
# Epoch: [ 2] [ 999/3165] time: 88.3299, d_loss: 1.42440391, g_loss: 0.65586287
# Saved model, epoch=2, counter=1001
# epoch=2, counter=1001
# Epoch: [ 2] [1199/3165] time: 90.4895, d_loss: 1.43890095, g_loss: 0.64617789
# Epoch: [ 2] [1399/3165] time: 87.6758, d_loss: 1.40904617, g_loss: 0.65067786
# Epoch: [ 2] [1599/3165] time: 87.9984, d_loss: 1.37419260, g_loss: 0.67073202
# Epoch: [ 2] [1799/3165] time: 87.8008, d_loss: 1.39617431, g_loss: 0.55173254
# Epoch: [ 2] [1999/3165] time: 87.7345, d_loss: 1.37743509, g_loss: 0.63713735
# Saved model, epoch=2, counter=2001
# epoch=2, counter=2001
# Epoch: [ 2] [2199/3165] time: 90.3971, d_loss: 1.35479498, g_loss: 0.64605641
# Epoch: [ 2] [2399/3165] time: 88.0731, d_loss: 1.38841546, g_loss: 0.56763554
# Epoch: [ 2] [2599/3165] time: 87.7876, d_loss: 1.37751794, g_loss: 0.75448978
# Epoch: [ 2] [2799/3165] time: 88.1856, d_loss: 1.31763673, g_loss: 0.64563596
# Epoch: [ 2] [2999/3165] time: 87.0286, d_loss: 1.51426554, g_loss: 0.61528528
# Saved model, epoch=2, counter=3001
# epoch=2, counter=3001
# epoch=2, counter=3166
# Epoch: [ 3] [ 199/3165] time: 162.9098, d_loss: 1.25746155, g_loss: 0.83899748
# Epoch: [ 3] [ 399/3165] time: 88.1050, d_loss: 1.44691157, g_loss: 0.52652735
# Epoch: [ 3] [ 599/3165] time: 88.1174, d_loss: 1.38816226, g_loss: 0.59895658
# Epoch: [ 3] [ 799/3165] time: 87.5047, d_loss: 1.39086604, g_loss: 0.48870873
# Epoch: [ 3] [ 999/3165] time: 87.7486, d_loss: 1.68439233, g_loss: 0.29870263
# Saved model, epoch=3, counter=1001
# epoch=3, counter=1001
# Epoch: [ 3] [1199/3165] time: 90.7052, d_loss: 1.31517518, g_loss: 0.42145902
# Epoch: [ 3] [1399/3165] time: 88.5834, d_loss: 1.20150495, g_loss: 0.63827193
# Epoch: [ 3] [1599/3165] time: 88.5164, d_loss: 1.69081950, g_loss: 0.28674269
# Epoch: [ 3] [1799/3165] time: 88.6413, d_loss: 1.34447241, g_loss: 0.58885884
# Epoch: [ 3] [1999/3165] time: 88.4870, d_loss: 1.15219676, g_loss: 0.67734671
# Saved model, epoch=3, counter=2001
# epoch=3, counter=2001
# Epoch: [ 3] [2199/3165] time: 91.2475, d_loss: 1.13985479, g_loss: 0.72233570
# Epoch: [ 3] [2399/3165] time: 88.8240, d_loss: 1.41961908, g_loss: 1.93223250
# Epoch: [ 3] [2599/3165] time: 88.9674, d_loss: 1.31216574, g_loss: 1.11152029
# Epoch: [ 3] [2799/3165] time: 89.0871, d_loss: 1.33854198, g_loss: 0.39775634
# Epoch: [ 3] [2999/3165] time: 88.8209, d_loss: 1.29596388, g_loss: 0.45888367
# Saved model, epoch=3, counter=3001
# epoch=3, counter=3001
# epoch=3, counter=3166
# Epoch: [ 4] [ 199/3165] time: 162.5591, d_loss: 1.09876609, g_loss: 1.09944201
# Epoch: [ 4] [ 399/3165] time: 87.7052, d_loss: 1.24442625, g_loss: 1.15598345
# Epoch: [ 4] [ 599/3165] time: 88.1100, d_loss: 0.72065985, g_loss: 1.30404294
# Epoch: [ 4] [ 799/3165] time: 88.1021, d_loss: 1.08799636, g_loss: 0.57125998
# Epoch: [ 4] [ 999/3165] time: 88.1468, d_loss: 1.93228197, g_loss: 2.28643227
# Saved model, epoch=4, counter=1001
# epoch=4, counter=1001
# Epoch: [ 4] [1199/3165] time: 90.8601, d_loss: 1.34179986, g_loss: 0.39492998
# Epoch: [ 4] [1399/3165] time: 88.2613, d_loss: 1.01613522, g_loss: 0.81253934
# Epoch: [ 4] [1599/3165] time: 87.5577, d_loss: 1.20511544, g_loss: 0.43326801
# Epoch: [ 4] [1799/3165] time: 87.7861, d_loss: 1.14190066, g_loss: 0.55371344
# Epoch: [ 4] [1999/3165] time: 87.6064, d_loss: 1.25571823, g_loss: 1.44890809
# Saved model, epoch=4, counter=2001
# epoch=4, counter=2001
# Epoch: [ 4] [2199/3165] time: 89.9373, d_loss: 1.31133020, g_loss: 0.45538485
# Epoch: [ 4] [2399/3165] time: 86.9243, d_loss: 1.86860359, g_loss: 0.21239071
# Epoch: [ 4] [2599/3165] time: 86.9871, d_loss: 1.04099393, g_loss: 1.00595748
# Epoch: [ 4] [2799/3165] time: 87.2641, d_loss: 1.50875080, g_loss: 0.33336779
# Epoch: [ 4] [2999/3165] time: 88.0054, d_loss: 0.95805460, g_loss: 1.24829352
# Saved model, epoch=4, counter=3001
# epoch=4, counter=3001
# epoch=4, counter=3166
# Epoch: [ 5] [ 199/3165] time: 163.2771, d_loss: 1.07855427, g_loss: 0.98732817
# Epoch: [ 5] [ 399/3165] time: 87.6616, d_loss: 1.09319651, g_loss: 0.95781755
# Epoch: [ 5] [ 599/3165] time: 87.4845, d_loss: 0.67722559, g_loss: 2.75591707
# Epoch: [ 5] [ 799/3165] time: 87.7405, d_loss: 1.61347008, g_loss: 0.29751953
# Epoch: [ 5] [ 999/3165] time: 87.6797, d_loss: 1.68177295, g_loss: 1.51178098
# Saved model, epoch=5, counter=1001
# epoch=5, counter=1001
# Epoch: [ 5] [1199/3165] time: 90.6079, d_loss: 1.10889566, g_loss: 0.62459576
# Epoch: [ 5] [1399/3165] time: 87.5780, d_loss: 0.97523403, g_loss: 1.11102486
# Epoch: [ 5] [1599/3165] time: 87.5678, d_loss: 1.78085673, g_loss: 0.25866982
# Epoch: [ 5] [1799/3165] time: 87.9549, d_loss: 1.62192988, g_loss: 0.29696834
# Epoch: [ 5] [1999/3165] time: 88.1776, d_loss: 0.96883011, g_loss: 0.80302197
# Saved model, epoch=5, counter=2001
# epoch=5, counter=2001
# Epoch: [ 5] [2199/3165] time: 90.2599, d_loss: 1.45099831, g_loss: 0.50869346
# Epoch: [ 5] [2399/3165] time: 88.1548, d_loss: 1.31486249, g_loss: 0.40280139
# Epoch: [ 5] [2599/3165] time: 88.1809, d_loss: 1.65388799, g_loss: 0.27024153
# Epoch: [ 5] [2799/3165] time: 88.1370, d_loss: 1.53478110, g_loss: 0.32922873
# Epoch: [ 5] [2999/3165] time: 88.5463, d_loss: 1.19718850, g_loss: 0.49079147
# Saved model, epoch=5, counter=3001
# epoch=5, counter=3001
# epoch=5, counter=3166
# Epoch: [ 6] [ 199/3165] time: 163.5330, d_loss: 1.43383396, g_loss: 0.39538753
# Epoch: [ 6] [ 399/3165] time: 87.5528, d_loss: 1.28715849, g_loss: 0.45916152
# Epoch: [ 6] [ 599/3165] time: 88.7664, d_loss: 1.13299930, g_loss: 0.62324798
# Epoch: [ 6] [ 799/3165] time: 88.0144, d_loss: 1.82473600, g_loss: 0.20877156
# Epoch: [ 6] [ 999/3165] time: 87.9811, d_loss: 1.36223865, g_loss: 2.17524838
# Saved model, epoch=6, counter=1001
# epoch=6, counter=1001
# Epoch: [ 6] [1199/3165] time: 91.5989, d_loss: 1.55169129, g_loss: 0.30592674
# Epoch: [ 6] [1399/3165] time: 87.0541, d_loss: 1.47052896, g_loss: 0.34150901
# Epoch: [ 6] [1599/3165] time: 86.9656, d_loss: 1.10048127, g_loss: 1.94845939
# Epoch: [ 6] [1799/3165] time: 87.9354, d_loss: 0.77974665, g_loss: 2.45166683
# Epoch: [ 6] [1999/3165] time: 87.5196, d_loss: 1.11095572, g_loss: 1.08212519
# Saved model, epoch=6, counter=2001
# epoch=6, counter=2001
# Epoch: [ 6] [2199/3165] time: 90.2679, d_loss: 2.44673920, g_loss: 0.10724410
# Epoch: [ 6] [2399/3165] time: 85.9804, d_loss: 0.87596464, g_loss: 0.80432165
# Epoch: [ 6] [2599/3165] time: 87.4468, d_loss: 1.61153829, g_loss: 0.28600973
# Epoch: [ 6] [2799/3165] time: 87.6207, d_loss: 2.05858135, g_loss: 0.18066087
# Epoch: [ 6] [2999/3165] time: 86.8188, d_loss: 1.71603155, g_loss: 0.27769315
# Saved model, epoch=6, counter=3001
# epoch=6, counter=3001
# epoch=6, counter=3166
# Epoch: [ 7] [ 199/3165] time: 163.0036, d_loss: 1.97142375, g_loss: 0.19463204
# Epoch: [ 7] [ 399/3165] time: 87.9318, d_loss: 1.38737655, g_loss: 0.62780678
# Epoch: [ 7] [ 599/3165] time: 88.0842, d_loss: 1.35223019, g_loss: 3.11838341
# Epoch: [ 7] [ 799/3165] time: 88.0673, d_loss: 2.32686567, g_loss: 0.12803197
# Epoch: [ 7] [ 999/3165] time: 87.7443, d_loss: 2.00089002, g_loss: 2.71590734
# Saved model, epoch=7, counter=1001
# epoch=7, counter=1001
# Epoch: [ 7] [1199/3165] time: 90.9428, d_loss: 1.32755113, g_loss: 0.46789473
# Epoch: [ 7] [1399/3165] time: 86.7596, d_loss: 2.16573000, g_loss: 0.15798137
# Epoch: [ 7] [1599/3165] time: 86.7001, d_loss: 2.10663390, g_loss: 0.16916475
# Epoch: [ 7] [1799/3165] time: 87.5399, d_loss: 0.62680465, g_loss: 0.96479911
# Epoch: [ 7] [1999/3165] time: 88.3179, d_loss: 1.93226302, g_loss: 0.23411191
# Saved model, epoch=7, counter=2001
# epoch=7, counter=2001
# Epoch: [ 7] [2199/3165] time: 94.6804, d_loss: 1.28923488, g_loss: 0.44073832
# Epoch: [ 7] [2399/3165] time: 90.6947, d_loss: 1.74497676, g_loss: 0.26326650
# Epoch: [ 7] [2599/3165] time: 90.5672, d_loss: 1.33269334, g_loss: 0.42693916
# Epoch: [ 7] [2799/3165] time: 90.1202, d_loss: 1.41856956, g_loss: 0.39763618
# Epoch: [ 7] [2999/3165] time: 88.0690, d_loss: 1.59889829, g_loss: 0.28673223
# Saved model, epoch=7, counter=3001
# epoch=7, counter=3001
# epoch=7, counter=3166
# Epoch: [ 8] [ 199/3165] time: 161.0883, d_loss: 2.25630474, g_loss: 0.13936444
# Epoch: [ 8] [ 399/3165] time: 86.6065, d_loss: 2.14890766, g_loss: 0.15884435
# Epoch: [ 8] [ 599/3165] time: 87.1203, d_loss: 1.85474062, g_loss: 0.22613634
# Epoch: [ 8] [ 799/3165] time: 86.8846, d_loss: 1.68211734, g_loss: 0.26668811
# Epoch: [ 8] [ 999/3165] time: 86.6734, d_loss: 2.92869258, g_loss: 3.19652414
# Saved model, epoch=8, counter=1001
# epoch=8, counter=1001
# Epoch: [ 8] [1199/3165] time: 89.7038, d_loss: 1.91648006, g_loss: 0.23094513
# Epoch: [ 8] [1399/3165] time: 87.1983, d_loss: 1.95206070, g_loss: 0.21675120
# Epoch: [ 8] [1599/3165] time: 87.3588, d_loss: 1.47392857, g_loss: 1.35485554
# Epoch: [ 8] [1799/3165] time: 87.4501, d_loss: 1.03220987, g_loss: 0.57251632
# Epoch: [ 8] [1999/3165] time: 87.6770, d_loss: 1.58251023, g_loss: 0.49035993
# Saved model, epoch=8, counter=2001
# epoch=8, counter=2001
# Epoch: [ 8] [2199/3165] time: 89.8292, d_loss: 1.91415954, g_loss: 0.21558695
# Epoch: [ 8] [2399/3165] time: 86.2946, d_loss: 0.21224290, g_loss: 2.07982612
# Epoch: [ 8] [2599/3165] time: 86.6547, d_loss: 1.45036781, g_loss: 0.38507891
# Epoch: [ 8] [2799/3165] time: 86.4865, d_loss: 1.58872342, g_loss: 0.37442067
# Epoch: [ 8] [2999/3165] time: 86.2126, d_loss: 1.32810211, g_loss: 0.41299689
# Saved model, epoch=8, counter=3001
# epoch=8, counter=3001
# epoch=8, counter=3166
# Epoch: [ 9] [ 199/3165] time: 160.7391, d_loss: 2.45924664, g_loss: 0.11651712
# Epoch: [ 9] [ 399/3165] time: 87.0637, d_loss: 2.60995626, g_loss: 0.09658073
# Epoch: [ 9] [ 599/3165] time: 86.9624, d_loss: 2.29609656, g_loss: 2.84630156
# Epoch: [ 9] [ 799/3165] time: 88.4641, d_loss: 2.26184440, g_loss: 0.14032032
# Epoch: [ 9] [ 999/3165] time: 87.0243, d_loss: 1.48223257, g_loss: 2.27467895
# Saved model, epoch=9, counter=1001
# epoch=9, counter=1001
# Epoch: [ 9] [1199/3165] time: 90.6877, d_loss: 1.64117706, g_loss: 0.29236418
# Epoch: [ 9] [1399/3165] time: 88.6182, d_loss: 2.03378034, g_loss: 0.18650204
# Epoch: [ 9] [1599/3165] time: 88.7773, d_loss: 1.61662006, g_loss: 0.38269782
# Epoch: [ 9] [1799/3165] time: 88.1540, d_loss: 1.58371878, g_loss: 0.28897801
# Epoch: [ 9] [1999/3165] time: 87.8297, d_loss: 1.24125683, g_loss: 2.07398462
# Saved model, epoch=9, counter=2001
# epoch=9, counter=2001
# Epoch: [ 9] [2199/3165] time: 90.5643, d_loss: 1.11533415, g_loss: 0.58341610
# Epoch: [ 9] [2399/3165] time: 88.2032, d_loss: 0.99119061, g_loss: 0.59071016
# Epoch: [ 9] [2599/3165] time: 87.6519, d_loss: 0.77006584, g_loss: 0.86022872
# Epoch: [ 9] [2799/3165] time: 88.4513, d_loss: 2.63819885, g_loss: 0.09345654
# Epoch: [ 9] [2999/3165] time: 88.2227, d_loss: 1.08146453, g_loss: 0.72955281
# Saved model, epoch=9, counter=3001
# epoch=9, counter=3001
# epoch=9, counter=3166
# Epoch: [10] [ 199/3165] time: 164.4207, d_loss: 2.19590473, g_loss: 0.20179358
# Epoch: [10] [ 399/3165] time: 87.9679, d_loss: 1.29341960, g_loss: 0.55264199
# Epoch: [10] [ 599/3165] time: 88.7104, d_loss: 1.97350693, g_loss: 0.19486919
# Epoch: [10] [ 799/3165] time: 88.0729, d_loss: 2.21747494, g_loss: 0.15870462
# Epoch: [10] [ 999/3165] time: 86.9074, d_loss: 1.01874173, g_loss: 0.55977535
# Saved model, epoch=10, counter=1001
# epoch=10, counter=1001
# Epoch: [10] [1199/3165] time: 91.0280, d_loss: 1.61915767, g_loss: 0.38610041
# Epoch: [10] [1399/3165] time: 88.1214, d_loss: 0.72225577, g_loss: 1.22296286
# Epoch: [10] [1599/3165] time: 88.2152, d_loss: 2.74970102, g_loss: 0.08453236
# Epoch: [10] [1799/3165] time: 86.9601, d_loss: 1.19865656, g_loss: 0.75403035
# Epoch: [10] [1999/3165] time: 87.2978, d_loss: 0.96781087, g_loss: 0.83380580
# Saved model, epoch=10, counter=2001
# epoch=10, counter=2001
# Epoch: [10] [2199/3165] time: 90.3028, d_loss: 2.51291537, g_loss: 0.11533424
# Epoch: [10] [2399/3165] time: 86.9990, d_loss: 1.69064724, g_loss: 0.35517216
# Epoch: [10] [2599/3165] time: 86.9841, d_loss: 2.36042047, g_loss: 0.13466635
# Epoch: [10] [2799/3165] time: 87.0665, d_loss: 2.09960628, g_loss: 0.16699314
# Epoch: [10] [2999/3165] time: 87.1320, d_loss: 2.41900563, g_loss: 0.13071197
# Saved model, epoch=10, counter=3001
# epoch=10, counter=3001
# epoch=10, counter=3166
# Epoch: [11] [ 199/3165] time: 163.5958, d_loss: 1.55668306, g_loss: 0.40128773
# Epoch: [11] [ 399/3165] time: 87.4950, d_loss: 1.31879032, g_loss: 0.77458596
# Epoch: [11] [ 599/3165] time: 87.9313, d_loss: 1.22007048, g_loss: 0.50502688
# Epoch: [11] [ 799/3165] time: 87.2839, d_loss: 2.23099160, g_loss: 0.14176640
# Epoch: [11] [ 999/3165] time: 88.1685, d_loss: 2.10865998, g_loss: 3.30140877
# Saved model, epoch=11, counter=1001
# epoch=11, counter=1001
# Epoch: [11] [1199/3165] time: 91.4763, d_loss: 2.03937292, g_loss: 0.18942583
# Epoch: [11] [1399/3165] time: 89.1839, d_loss: 2.69365358, g_loss: 0.09566296
# Epoch: [11] [1599/3165] time: 87.2015, d_loss: 2.19494796, g_loss: 0.16255805
# Epoch: [11] [1799/3165] time: 88.2270, d_loss: 2.61564326, g_loss: 0.11265884
# Epoch: [11] [1999/3165] time: 88.5341, d_loss: 0.85800803, g_loss: 1.79558420
# Saved model, epoch=11, counter=2001
# epoch=11, counter=2001
# Epoch: [11] [2199/3165] time: 92.9461, d_loss: 1.49393010, g_loss: 0.34147581
# Epoch: [11] [2399/3165] time: 87.2136, d_loss: 3.61195898, g_loss: 0.04005896
# Epoch: [11] [2599/3165] time: 87.6953, d_loss: 2.97965479, g_loss: 0.06819049
# Epoch: [11] [2799/3165] time: 87.3997, d_loss: 1.25799775, g_loss: 0.47246149
# Epoch: [11] [2999/3165] time: 87.2793, d_loss: 1.33170271, g_loss: 0.43226779
# Saved model, epoch=11, counter=3001
# epoch=11, counter=3001
# epoch=11, counter=3166
# Epoch: [12] [ 199/3165] time: 161.4869, d_loss: 2.02834654, g_loss: 0.17636859
# Epoch: [12] [ 399/3165] time: 84.7557, d_loss: 1.15574777, g_loss: 0.52901453
# Epoch: [12] [ 599/3165] time: 85.4718, d_loss: 2.09346914, g_loss: 0.17410538
# Epoch: [12] [ 799/3165] time: 86.0187, d_loss: 2.46508145, g_loss: 0.11256017
# Epoch: [12] [ 999/3165] time: 85.0223, d_loss: 2.21797323, g_loss: 0.16620356
# Saved model, epoch=12, counter=1001
# epoch=12, counter=1001
# Epoch: [12] [1199/3165] time: 90.2225, d_loss: 3.97836924, g_loss: 0.02741839
# Epoch: [12] [1399/3165] time: 87.6789, d_loss: 2.11324620, g_loss: 0.15291901
# Epoch: [12] [1599/3165] time: 87.5540, d_loss: 1.93743479, g_loss: 0.24324867
# Epoch: [12] [1799/3165] time: 85.8464, d_loss: 1.76630545, g_loss: 0.29186463
# Epoch: [12] [1999/3165] time: 87.0564, d_loss: 1.57357407, g_loss: 0.44663197
# Saved model, epoch=12, counter=2001
# epoch=12, counter=2001
# Epoch: [12] [2199/3165] time: 87.9900, d_loss: 2.32749581, g_loss: 0.13009039
# Epoch: [12] [2399/3165] time: 84.8177, d_loss: 0.80625904, g_loss: 0.79520011
# Epoch: [12] [2599/3165] time: 86.1362, d_loss: 1.01507497, g_loss: 0.63706905
# Epoch: [12] [2799/3165] time: 87.8183, d_loss: 2.47221923, g_loss: 0.12647414
# Epoch: [12] [2999/3165] time: 87.2055, d_loss: 1.13349140, g_loss: 0.48996577
# Saved model, epoch=12, counter=3001
# epoch=12, counter=3001
# epoch=12, counter=3166
# Epoch: [13] [ 199/3165] time: 160.0800, d_loss: 3.37460804, g_loss: 0.05066173
# Epoch: [13] [ 399/3165] time: 87.2504, d_loss: 3.76210976, g_loss: 0.03753291
# Epoch: [13] [ 599/3165] time: 87.8430, d_loss: 2.93679285, g_loss: 5.61380959
# Epoch: [13] [ 799/3165] time: 87.5254, d_loss: 2.38915896, g_loss: 0.13684155
# Epoch: [13] [ 999/3165] time: 87.6507, d_loss: 1.71177006, g_loss: 0.37974709
# Saved model, epoch=13, counter=1001
# epoch=13, counter=1001
# Epoch: [13] [1199/3165] time: 91.4097, d_loss: 2.51141310, g_loss: 0.10599308
# Epoch: [13] [1399/3165] time: 88.1587, d_loss: 2.07383680, g_loss: 0.21251965
# Epoch: [13] [1599/3165] time: 87.2276, d_loss: 1.84109509, g_loss: 0.26198542
# Epoch: [13] [1799/3165] time: 88.1030, d_loss: 2.21807933, g_loss: 0.16733012
# Epoch: [13] [1999/3165] time: 88.4394, d_loss: 0.99146926, g_loss: 1.08363676
# Saved model, epoch=13, counter=2001
# epoch=13, counter=2001
# Epoch: [13] [2199/3165] time: 91.4966, d_loss: 1.26811779, g_loss: 0.65944612
# Epoch: [13] [2399/3165] time: 87.9607, d_loss: 2.80329514, g_loss: 0.10678507
# Epoch: [13] [2599/3165] time: 87.8308, d_loss: 2.47502208, g_loss: 0.11935847
# Epoch: [13] [2799/3165] time: 86.8283, d_loss: 1.42500830, g_loss: 0.44615877
# Epoch: [13] [2999/3165] time: 87.5501, d_loss: 0.94014740, g_loss: 0.67777145
# Saved model, epoch=13, counter=3001
# epoch=13, counter=3001
# epoch=13, counter=3166
# Epoch: [14] [ 199/3165] time: 164.1221, d_loss: 2.63297725, g_loss: 0.10625805
# Epoch: [14] [ 399/3165] time: 87.8530, d_loss: 0.93948221, g_loss: 0.74851811
# Epoch: [14] [ 599/3165] time: 87.8431, d_loss: 0.00136102, g_loss: 12.49326706
# Epoch: [14] [ 799/3165] time: 87.9604, d_loss: 0.08518507, g_loss: 3.11377597
# Epoch: [14] [ 999/3165] time: 87.6726, d_loss: 0.10564899, g_loss: 3.39204264
# Saved model, epoch=14, counter=1001
# epoch=14, counter=1001
# Epoch: [14] [1199/3165] time: 91.5141, d_loss: 0.18398252, g_loss: 2.96130633
# Epoch: [14] [1399/3165] time: 87.6825, d_loss: 0.01465424, g_loss: 8.80452538
# Epoch: [14] [1599/3165] time: 88.0620, d_loss: 0.44981495, g_loss: 1.27457631
# Epoch: [14] [1799/3165] time: 88.1098, d_loss: 0.08794531, g_loss: 3.40374899
# Epoch: [14] [1999/3165] time: 87.8341, d_loss: 0.03404942, g_loss: 4.90784073
# Saved model, epoch=14, counter=2001
# epoch=14, counter=2001
# Epoch: [14] [2199/3165] time: 91.5911, d_loss: 0.30764094, g_loss: 1.88666105
# Epoch: [14] [2399/3165] time: 87.6550, d_loss: 0.48041314, g_loss: 1.48746872
# Epoch: [14] [2599/3165] time: 87.9400, d_loss: 0.34577629, g_loss: 1.95442200
# Epoch: [14] [2799/3165] time: 88.3490, d_loss: 0.46080396, g_loss: 1.51069248
# Epoch: [14] [2999/3165] time: 88.8632, d_loss: 0.34440473, g_loss: 1.80984855
# Saved model, epoch=14, counter=3001
# epoch=14, counter=3001
# epoch=14, counter=3166
# Epoch: [15] [ 199/3165] time: 163.2446, d_loss: 0.37123609, g_loss: 1.72318006
# Epoch: [15] [ 399/3165] time: 87.5235, d_loss: 0.46759230, g_loss: 1.56500292
# Epoch: [15] [ 599/3165] time: 87.4853, d_loss: 1.07465553, g_loss: 0.72258592
# Epoch: [15] [ 799/3165] time: 88.1246, d_loss: 0.17036742, g_loss: 4.93508148
# Epoch: [15] [ 999/3165] time: 88.3824, d_loss: 0.24885179, g_loss: 2.25531197
# Saved model, epoch=15, counter=1001
# epoch=15, counter=1001
# Epoch: [15] [1199/3165] time: 90.4188, d_loss: 0.24788164, g_loss: 2.94142580
# Epoch: [15] [1399/3165] time: 89.4722, d_loss: 0.17576101, g_loss: 3.17402220
# Epoch: [15] [1599/3165] time: 88.2545, d_loss: 0.38976911, g_loss: 1.60866928
# Epoch: [15] [1799/3165] time: 87.8442, d_loss: 0.72573853, g_loss: 2.25693846
# Epoch: [15] [1999/3165] time: 87.7604, d_loss: 0.56232303, g_loss: 1.24495947
# Saved model, epoch=15, counter=2001
# epoch=15, counter=2001
# Epoch: [15] [2199/3165] time: 90.8534, d_loss: 1.07402909, g_loss: 0.69221646
# Epoch: [15] [2399/3165] time: 88.5062, d_loss: 0.16297309, g_loss: 2.38932157
# Epoch: [15] [2599/3165] time: 87.5619, d_loss: 0.85218012, g_loss: 0.95276308
# Epoch: [15] [2799/3165] time: 87.8893, d_loss: 0.77989215, g_loss: 0.96294641
# Epoch: [15] [2999/3165] time: 87.9151, d_loss: 0.56661546, g_loss: 1.16364336
# Saved model, epoch=15, counter=3001
# epoch=15, counter=3001
# epoch=15, counter=3166
# Epoch: [16] [ 199/3165] time: 163.0752, d_loss: 0.82404870, g_loss: 0.71745503
# Epoch: [16] [ 399/3165] time: 86.6716, d_loss: 0.23753186, g_loss: 2.15896058
# Epoch: [16] [ 599/3165] time: 86.8088, d_loss: 0.74962819, g_loss: 0.94306624
# Epoch: [16] [ 799/3165] time: 86.3651, d_loss: 0.65177494, g_loss: 1.00238895
# Epoch: [16] [ 999/3165] time: 85.8727, d_loss: 0.48870689, g_loss: 1.75850773
# Saved model, epoch=16, counter=1001
# epoch=16, counter=1001
# Epoch: [16] [1199/3165] time: 89.3442, d_loss: 0.41515329, g_loss: 1.40785217
# Epoch: [16] [1399/3165] time: 86.7828, d_loss: 0.30452701, g_loss: 1.87690735
# Epoch: [16] [1599/3165] time: 86.4580, d_loss: 0.46455440, g_loss: 1.56401920
# Epoch: [16] [1799/3165] time: 86.8736, d_loss: 0.73253310, g_loss: 0.95868903
# Epoch: [16] [1999/3165] time: 88.5321, d_loss: 1.16977286, g_loss: 0.51947308
# Saved model, epoch=16, counter=2001
# epoch=16, counter=2001
# Epoch: [16] [2199/3165] time: 90.2106, d_loss: 0.02662014, g_loss: 4.56468582
# Epoch: [16] [2399/3165] time: 87.4492, d_loss: 0.00467762, g_loss: 6.88846493
# Epoch: [16] [2599/3165] time: 86.6943, d_loss: 0.25593817, g_loss: 2.24778366
# Epoch: [16] [2799/3165] time: 90.3056, d_loss: 0.19873920, g_loss: 2.39469433
# Epoch: [16] [2999/3165] time: 88.3764, d_loss: 0.63436449, g_loss: 1.10129142
# Saved model, epoch=16, counter=3001
# epoch=16, counter=3001
# epoch=16, counter=3166
# Epoch: [17] [ 199/3165] time: 166.1839, d_loss: 1.64673471, g_loss: 0.32105017
# Epoch: [17] [ 399/3165] time: 87.7727, d_loss: 0.70101994, g_loss: 1.06073093
# Epoch: [17] [ 599/3165] time: 88.5276, d_loss: 0.87017030, g_loss: 0.85681850
# Epoch: [17] [ 799/3165] time: 87.4206, d_loss: 2.33457136, g_loss: 0.18028255
# Epoch: [17] [ 999/3165] time: 87.0131, d_loss: 0.97466469, g_loss: 0.59051210
# Saved model, epoch=17, counter=1001
# epoch=17, counter=1001
# Epoch: [17] [1199/3165] time: 90.1953, d_loss: 0.53489226, g_loss: 1.65675581
# Epoch: [17] [1399/3165] time: 87.6154, d_loss: 0.62488216, g_loss: 1.19131899
# Epoch: [17] [1599/3165] time: 85.7988, d_loss: 2.28202915, g_loss: 5.51130199
# Epoch: [17] [1799/3165] time: 86.9124, d_loss: 0.66426933, g_loss: 1.37050891
# Epoch: [17] [1999/3165] time: 88.2794, d_loss: 0.01397707, g_loss: 4.99677467
# Saved model, epoch=17, counter=2001
# epoch=17, counter=2001
# Epoch: [17] [2199/3165] time: 91.2609, d_loss: 0.00632158, g_loss: 7.49004889
# Epoch: [17] [2399/3165] time: 88.2992, d_loss: 0.01169978, g_loss: 5.12887573
# Epoch: [17] [2599/3165] time: 86.5416, d_loss: 0.63773078, g_loss: 1.85882473
# Epoch: [17] [2799/3165] time: 86.9613, d_loss: 0.05976626, g_loss: 6.04810143
# Epoch: [17] [2999/3165] time: 87.7806, d_loss: 0.47976500, g_loss: 10.41049480
# Saved model, epoch=17, counter=3001
# epoch=17, counter=3001
# epoch=17, counter=3166
# Epoch: [18] [ 199/3165] time: 165.5696, d_loss: 0.11569007, g_loss: 3.44601011
# Epoch: [18] [ 399/3165] time: 90.2239, d_loss: 0.19499455, g_loss: 2.34718847
# Epoch: [18] [ 599/3165] time: 89.9260, d_loss: 0.05079056, g_loss: 6.04976845
# Epoch: [18] [ 799/3165] time: 89.2413, d_loss: 0.13753194, g_loss: 2.40897989
# Epoch: [18] [ 999/3165] time: 88.7823, d_loss: 0.02355794, g_loss: 6.10141897
# Saved model, epoch=18, counter=1001
# epoch=18, counter=1001
# Epoch: [18] [1199/3165] time: 92.0582, d_loss: 0.03579364, g_loss: 3.82851887
# Epoch: [18] [1399/3165] time: 88.7617, d_loss: 0.09514560, g_loss: 3.55960250
# Epoch: [18] [1599/3165] time: 89.6558, d_loss: 0.25263357, g_loss: 1.86168480
# Epoch: [18] [1799/3165] time: 89.7253, d_loss: 0.09948736, g_loss: 3.70862293
# Epoch: [18] [1999/3165] time: 90.3261, d_loss: 0.18935440, g_loss: 1.98363113
# Saved model, epoch=18, counter=2001
# epoch=18, counter=2001
# Epoch: [18] [2199/3165] time: 92.8743, d_loss: 0.10179447, g_loss: 11.66625786
# Epoch: [18] [2399/3165] time: 88.4098, d_loss: 0.09396742, g_loss: 2.64573097
# Epoch: [18] [2599/3165] time: 89.8835, d_loss: 0.12088915, g_loss: 3.98856091
# Epoch: [18] [2799/3165] time: 88.5986, d_loss: 0.10299271, g_loss: 2.77501345
# Epoch: [18] [2999/3165] time: 88.4543, d_loss: 0.04270499, g_loss: 6.82769012
# Saved model, epoch=18, counter=3001
# epoch=18, counter=3001
# epoch=18, counter=3166
# Epoch: [19] [ 199/3165] time: 162.5823, d_loss: 0.11608404, g_loss: 2.47634983
# Epoch: [19] [ 399/3165] time: 88.0034, d_loss: 0.06213173, g_loss: 4.23629379
# Epoch: [19] [ 599/3165] time: 88.3960, d_loss: 0.04027509, g_loss: 3.86777210
# Epoch: [19] [ 799/3165] time: 86.9537, d_loss: 0.01674322, g_loss: 11.05764198
# Epoch: [19] [ 999/3165] time: 87.6458, d_loss: 0.28788504, g_loss: 9.10587120
# Saved model, epoch=19, counter=1001
# epoch=19, counter=1001
# Epoch: [19] [1199/3165] time: 89.6950, d_loss: 0.15552489, g_loss: 2.39450121
# Epoch: [19] [1399/3165] time: 87.2970, d_loss: 0.09635401, g_loss: 3.20233202
# Epoch: [19] [1599/3165] time: 86.8569, d_loss: 0.23304738, g_loss: 1.81967723
# Epoch: [19] [1799/3165] time: 87.7867, d_loss: 0.13836753, g_loss: 2.63583946
# Epoch: [19] [1999/3165] time: 88.3249, d_loss: 0.05873436, g_loss: 3.80119419
# Saved model, epoch=19, counter=2001
# epoch=19, counter=2001
# Epoch: [19] [2199/3165] time: 90.9964, d_loss: 0.08969117, g_loss: 6.22348452
# Epoch: [19] [2399/3165] time: 87.7543, d_loss: 0.10386308, g_loss: 6.60511780
# Epoch: [19] [2599/3165] time: 88.3796, d_loss: 0.15871216, g_loss: 2.29054713
# Epoch: [19] [2799/3165] time: 89.1535, d_loss: 0.12505661, g_loss: 2.53980064
# Epoch: [19] [2999/3165] time: 88.2014, d_loss: 0.37667444, g_loss: 1.40090013
# Saved model, epoch=19, counter=3001
# epoch=19, counter=3001
# epoch=19, counter=3166

# %% [markdown]
# If you generated something that looks like a face - it's cool! Add 2 points to your mark.

# %% [markdown]
# ### Display some intermediate results to show generated faces

# %%
# %matplotlib inline
import cv2
import matplotlib.pyplot as plt
generated_img_file = 'C:\\exercises\\Coursera_DLCV\\Assignments\\gan_faces\\sample_faces\\train_49_3165.png'
img = cv2.imread(generated_img_file)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %% [markdown]
# ## Face interpolation (1 point)

# %% [markdown]
# Let's interpolate between faces: generate two vectors $z_1$ and $z_2$ and get a batch of vectors of the form $\alpha\cdot z_1 + (1- \alpha)\cdot  z_2, \alpha \in [0,1].$ Generate faces on them and look at results. The generator displays pictures in the range from -1 to 1, so use the inverse transform function from the file utils.py.

# %%
z1_z2 = np.random.uniform(-1, 1, [2, Z_DIM]).astype(np.float64)
alpha = np.linspace(0, 1, 64)
batchz = np.zeros((alpha.shape[0], Z_DIM))
for i in range(alpha.shape[0]):
    batchz[i,:] = z1_z2[0, :] * alpha[i] + (1 - alpha[i]) * z1_z2[1, :]

batchz = batchz.astype(np.float32)

# %%
with tf.Session() as sess:
    load(sess, "C:\\exercises\\Coursera_DLCV\\Assignments\\gan_faces\\checkpoint")
    samples = sess.run(G, feed_dict={z: batchz, is_training: False} )
# Out:
# INFO:tensorflow:Restoring parameters from C:\exercises\Coursera_DLCV\Assignments\gan_faces\checkpoint\dcgan.model

# %%
samples_inv = (inverse_transform(samples) * 255).astype(int)

# %%
num_imgs = samples_inv.shape[0]
import os
output_dir = "C:\\exercises\\Coursera_DLCV\\Assignments\\gan_faces\\interpolated_faces"
for i in range(num_imgs):
    img_i = samples_inv[i, :, :, :]
    img_i = np.reshape(img_i, (64, 64, 3))
    img_i = img_i.astype(np.uint8)
    img_i = cv2.cvtColor(img_i, cv2.COLOR_BGR2RGB)
    file = os.path.join(output_dir, "interpolate_faces_"+str(i)+".jpg")
    cv2.imwrite(file, img_i)

# %%
w=8
h=8
fig=plt.figure(figsize=(8, 8))
columns = 8
rows = 8
for i in range(1, columns*rows +1):
    img = samples_inv[i-1, :, :, :].astype(np.uint8)
    #img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    fig.add_subplot(rows, columns, i)
    plt.axis('off')
    plt.imshow(img)
plt.show()

# %% [markdown]
# ## Adding a smile (1 point + 1 point for good results)

# %% [markdown]
# Let's make face smiling. Find several vectors z, such that the generator generates smiling faces and not. Five vectors in every group should be enough (but the more, the better).

# %% [markdown]
# Calculate "smile vector" as mean of vectors z with generated smile on it minus mean of vectors z with generated not smile on it.

# %% [markdown]
# Look at the result of applying the smile vector: compare the results of generation before and after the addition of the smile vector.

# %% [markdown]
# If faces looks really cool, add bonus 1 point to your score.

# %%
b = [10, 11, 15]
c = [15, 12, 20]
d = [21, 12, 14]
import numpy as np
a = [b, c, d]
for i in range(len(a)):
    a[i] = np.clip(a[i], 10, 15)
print(b, c, d)
# Out:
# [10, 11, 15] [15, 12, 20] [21, 12, 14]

# %%
a=1
b=a
b=3
print(a, b)
# Out:
# 1 3
